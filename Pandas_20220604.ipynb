# %%
import pandas as pd

# %%
len(dir(pd))
# Out:
# 141

# %%
## Pandas Series 

a = [10,20,30]

ser = pd.Series(a , index = ['a','b','c'])
print(ser)

type(ser)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
# pandas.core.series.Series

# %%
#import pandas as pd 

di = {"A":10,"B":20,"C":30,"D":40}

se = pd.Series(di)

print(se)

print(di.keys())
print(di.values())
# Out:
# A    10
# B    20
# C    30
# D    40
# dtype: int64
# dict_keys(['A', 'B', 'C', 'D'])
# dict_values([10, 20, 30, 40])

# %%
## Data frames 

df1 = pd.DataFrame()

print(df1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
## Data frames 

ls = [10,20,30,40,50,60]

df1 = pd.DataFrame(ls)

print(df1)
print(type(df1))
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# 5  60
# <class 'pandas.core.frame.DataFrame'>

# %%
## Data frames 

D = {"Name":['n1','n2','n3','n4'], "Age":[23,45,65,43]}

df1 = pd.DataFrame(D, index =['q','w','e','r'])

print(df1)
print(type(df1))
# Out:
#   Name  Age
# q   n1   23
# w   n2   45
# e   n3   65
# r   n4   43
# <class 'pandas.core.frame.DataFrame'>

# %%
## Data frames 

ls = [10,20,30,40,50,60]

df1 = pd.DataFrame(ls,index=[23,34,45,56,67,78],columns=["NEWCOL"])

print(df1)
print(type(df1))
# Out:
#     NEWCOL
# 23      10
# 34      20
# 45      30
# 56      40
# 67      50
# 78      60
# <class 'pandas.core.frame.DataFrame'>

# %%
df1.rename(columns={"NEWCOL":'Newcolz'})
# Out:
#     Newcolz
# 23       10
# 34       20
# 45       30
# 56       40
# 67       50
# 78       60

# %%
df1.columns = ["MyCOl"]
df1
# Out:
#     MyCOl
# 23     10
# 34     20
# 45     30
# 56     40
# 67     50
# 78     60

# %%
## Reading a CSV 

import pandas as pd 

df = pd.read_csv("C:/Users/AdmiN/Desktop/IP/DS/Data_Science_with_Python_Module_1_To_5/Module 4_Pandas/Code/Pandas/mtcars2.csv")
df1 = df
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
print(df.shape)
print(df1.shape)
# Out:
# (32, 13)
# (32, 13)

# %%
pd.concat([df,df1],axis = 1)
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
## Data frames 

D = {"Name":['n1','n2','n3','n4'], "Age":[23,45,65,43]}

df1 = pd.DataFrame(D, index =['q','w','e','r'])

df2 = pd.DataFrame(D, index =['q','w','e','r'])

# %%
df1
# Out:
#   Name  Age
# q   n1   23
# w   n2   45
# e   n3   65
# r   n4   43

# %%
df2
# Out:
#   Name  Age
# q   n1   23
# w   n2   45
# e   n3   65
# r   n4   43

# %%
pd.concat([df1,df2],axis = 1)
# Out:
#   Name  Age Name  Age
# q   n1   23   n1   23
# w   n2   45   n2   45
# e   n3   65   n3   65
# r   n4   43   n4   43

# %%
## Sameer question for work
# !pip install pyxlsb

import pandas as pd
df1 = pd.read_excel('C:/Users/AdmiN/Desktop/test1.xlsb', engine='pyxlsb')
df2 = pd.read_excel('C:/Users/AdmiN/Desktop/test2.xlsb', engine='pyxlsb')

df3 = pd.concat([df1,df2],axis=1)

df3.to_csv("Myfile.csv")

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\AdmiN\\Desktop\\IP\\DS\\Data_Science_with_Python_Module_1_To_5'

# %%
## Analysing the dataset 

df = pd.read_csv(r"C:\Users\AdmiN\Desktop\IP\DS\Data_Science_with_Python_Module_1_To_5\Module 4_Pandas\Code\Pandas\mtcars2.csv")
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
df.head()
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
df.tail()
# Out:
#     S.No      Unnamed: 1   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  \
# 27    28    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1
# 28    29  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1
# 29    30    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1
# 30    31   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1
# 31    32      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1
#
#     gear  carb
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
df.shape
# Out:
# (32, 13)

# %%
df.size
# Out:
# 416

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.No        32 non-null     int64
#  1   Unnamed: 1  32 non-null     object
#  2   mpg         32 non-null     float64
#  3   cyl         32 non-null     int64
#  4   disp        32 non-null     float64
#  5   hp          32 non-null     int64
#  6   drat        32 non-null     float64
#  7   wt          32 non-null     float64
#  8   qsec        29 non-null     float64
#  9   vs          32 non-null     int64
#  10  am          32 non-null     int64
#  11  gear        32 non-null     int64
#  12  carb        32 non-null     int64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 3.4+ KB

# %%
df.describe()
# Out:
#             S.No        mpg        cyl        disp          hp       drat  \
# count  32.000000  32.000000  32.000000   32.000000   32.000000  32.000000
# mean   16.500000  20.090625   6.187500  230.721875  146.687500   3.596563
# std     9.380832   6.026948   1.785922  123.938694   68.562868   0.534679
# min     1.000000  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%     8.750000  15.425000   4.000000  120.825000   96.500000   3.080000
# 50%    16.500000  19.200000   6.000000  196.300000  123.000000   3.695000
# 75%    24.250000  22.800000   8.000000  326.000000  180.000000   3.920000
# max    32.000000  33.900000   8.000000  472.000000  335.000000   4.930000
#
#               wt       qsec         vs         am       gear     carb
# count  32.000000  29.000000  32.000000  32.000000  32.000000  32.0000
# mean    3.217250  17.674828   0.437500   0.406250   3.687500   2.8125
# std     0.978457   1.780394   0.504016   0.498991   0.737804   1.6152
# ...

# %%
df.count()
# Out:
# S.No          32
# Unnamed: 1    32
# mpg           32
# cyl           32
# disp          32
# hp            32
# drat          32
# wt            32
# qsec          29
# vs            32
# am            32
# gear          32
# carb          32
# dtype: int64

# %%
df.min()
# Out:
# S.No                    1
# Unnamed: 1    AMC Javelin
# mpg                  10.4
# cyl                     4
# disp                 71.1
# hp                     52
# drat                 2.76
# wt                  1.513
# qsec                 14.5
# vs                      0
# am                      0
# gear                    3
# carb                    1
# dtype: object

# %%
df.max()
# Out:
# S.No                  32
# Unnamed: 1    Volvo 142E
# mpg                 33.9
# cyl                    8
# disp               472.0
# hp                   335
# drat                4.93
# wt                 5.424
# qsec                22.9
# vs                     1
# am                     1
# gear                   5
# carb                   8
# dtype: object

# %%
df.mean()
# Out:
# C:\Users\AdmiN\AppData\Local\Temp\ipykernel_4464\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# S.No     16.500000
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.674828
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\AdmiN\AppData\Local\Temp\ipykernel_4464\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# S.No     16.500
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.420
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
df["mpg"].mean()
# Out:
# 20.090624999999996

# %%
df.std()
# Out:
# C:\Users\AdmiN\AppData\Local\Temp\ipykernel_4464\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# S.No      9.380832
# mpg       6.026948
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.780394
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64
