# %%
## Importing the data 

import pandas as pd 
df = pd.read_csv(r"C:\Users\AdmiN\Desktop\IP\DS\Data_Science_with_Python_Module_1_To_5\Module 4_Pandas\Code\Pandas\mtcars2.csv")

# %%
df.head(10)
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620    NaN   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875    NaN   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320    NaN   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215    NaN   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440    NaN   0   0
# 5     6            Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1   0
# 6     7         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7     8          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8     9           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9    10           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2
# 5     3     1
# ...

# %%
# replace missing values with mean

df.fillna(df.qsec.mean())
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt     qsec  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  17.6675
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.6675
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  17.6675
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  17.6675
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.6675
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460  17.6675
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.8400
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.0000
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.9000
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.3000
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.9000
# ...

# %%
df.drop(columns=['vs','am'])
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620    NaN
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875    NaN
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320    NaN
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215    NaN
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440    NaN
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40
# ...

# %%
## Index by position & label ( location )

# iloc

df.iloc[ : , : ]
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620    NaN   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875    NaN   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320    NaN   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215    NaN   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440    NaN   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
## Index by position & label ( location )

# loc

df.loc[ : , :"mpg"]
# Out:
#     S.No           Unnamed: 1   mpg
# 0      1            Mazda RX4  21.0
# 1      2        Mazda RX4 Wag  21.0
# 2      3           Datsun 710  22.8
# 3      4       Hornet 4 Drive  21.4
# 4      5    Hornet Sportabout  18.7
# 5      6              Valiant  18.1
# 6      7           Duster 360  14.3
# 7      8            Merc 240D  24.4
# 8      9             Merc 230  22.8
# 9     10             Merc 280  19.2
# 10    11            Merc 280C  17.8
# 11    12           Merc 450SE  16.4
# 12    13           Merc 450SL  17.3
# 13    14          Merc 450SLC  15.2
# 14    15   Cadillac Fleetwood  10.4
# 15    16  Lincoln Continental  10.4
# 16    17    Chrysler Imperial  14.7
# 17    18             Fiat 128  32.4
# 18    19          Honda Civic  30.4
# 19    20       Toyota Corolla  33.9
# 20    21        Toyota Corona  21.5
# 21    22     Dodge Challenger  15.5
# 22    23          AMC Javelin  15.2
# 23    24           Camaro Z28  13.3
# 24    25     Pontiac Firebird  19.2
# ...

# %%
df.loc[4:4,:]
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  \
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.44   NaN   0   0
#
#    gear  carb
# 4     3     2

# %%
df.loc[7:13,"Unnamed: 1":"Unnamed: 1"]
# Out:
#      Unnamed: 1
# 7     Merc 240D
# 8      Merc 230
# 9      Merc 280
# 10    Merc 280C
# 11   Merc 450SE
# 12   Merc 450SL
# 13  Merc 450SLC

# %%
df.loc[7:13,["Unnamed: 1","mpg","cyl","gear"]]
# Out:
#      Unnamed: 1   mpg  cyl  gear
# 7     Merc 240D  24.4    4     4
# 8      Merc 230  22.8    4     4
# 9      Merc 280  19.2    6     4
# 10    Merc 280C  17.8    6     4
# 11   Merc 450SE  16.4    8     3
# 12   Merc 450SL  17.3    8     3
# 13  Merc 450SLC  15.2    8     3

# %%
df["vs"]=1
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620    NaN   1
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875    NaN   1
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320    NaN   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215    NaN   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440    NaN   1
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   1
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
df
df["kmpl"]=df["mpg"]*1.3
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620    NaN   1
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875    NaN   1
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320    NaN   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215    NaN   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440    NaN   1
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   1
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
a = lambda x : x*2.4

df["kmpl2"] = df["mpg"].apply(a)
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620    NaN   1
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875    NaN   1
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320    NaN   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215    NaN   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440    NaN   1
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   1
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
## Sorting 
df.sort_values(by="Unnamed: 1")
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   1
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   1
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   1
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   1
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320    NaN   1
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   1
# 29    30         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   1
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200    NaN   1
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935    NaN   1
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   1
# ...

# %%
df.sort_values(by="mpg", ascending = False)
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 19    20       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200    NaN   1
# 27    28         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935    NaN   1
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   1
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320    NaN   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 20    21        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1
# 31    32           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1
# ...

# %%
df.sort_values(by=["cyl","gear"], ascending = False)
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   1
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   1
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   1
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   1
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   1
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   1
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   1
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   1
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   1
# ...

# %%
df.sort_values(by=["cyl","gear"], ascending = [False,True])
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   1
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   1
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   1
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   1
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   1
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   1
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   1
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   1
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   1
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   1
# ...

# %%
df.loc[:,["mpg","vs","gear"]]
# Out:
#      mpg  vs  gear
# 0   21.0   1     4
# 1   21.0   1     4
# 2   22.8   1     4
# 3   21.4   1     3
# 4   18.7   1     3
# 5   18.1   1     3
# 6   14.3   1     3
# 7   24.4   1     4
# 8   22.8   1     4
# 9   19.2   1     4
# 10  17.8   1     4
# 11  16.4   1     3
# 12  17.3   1     3
# 13  15.2   1     3
# 14  10.4   1     3
# 15  10.4   1     3
# 16  14.7   1     3
# 17  32.4   1     4
# 18  30.4   1     4
# 19  33.9   1     4
# 20  21.5   1     3
# 21  15.5   1     3
# 22  15.2   1     3
# 23  13.3   1     3
# 24  19.2   1     3
# 25  27.3   1     4
# 26  26.0   1     5
# 27  30.4   1     5
# 28  15.8   1     5
# 29  19.7   1     5
# 30  15.0   1     5
# 31  21.4   1     4

# %%
df[df["Unnamed: 1"].str.startswith("Merc")]
# Out:
#     S.No   Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  \
# 7      8    Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0   1   0     4
# 8      9     Merc 230  22.8    4  140.8   95  3.92  3.15  22.9   1   0     4
# 9     10     Merc 280  19.2    6  167.6  123  3.92  3.44  18.3   1   0     4
# 10    11    Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9   1   0     4
# 11    12   Merc 450SE  16.4    8  275.8  180  3.07  4.07  17.4   1   0     3
# 12    13   Merc 450SL  17.3    8  275.8  180  3.07  3.73  17.6   1   0     3
# 13    14  Merc 450SLC  15.2    8  275.8  180  3.07  3.78  18.0   1   0     3
#
#     carb   kmpl  kmpl2
# 7      2  31.72  58.56
# 8      2  29.64  54.72
# 9      4  24.96  46.08
# 10     4  23.14  42.72
# 11     3  21.32  39.36
# 12     3  22.49  41.52
# 13     3  19.76  36.48

# %%
## Filter 
df[(df.cyl > 6) | (df.gear >4)]
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   1
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   1
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   1
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   1
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   1
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   1
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   1
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   1
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   1
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   1
# ...

# %%
df[df["Unnamed: 1"].str.contains("Merc")]
# Out:
#     S.No   Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  \
# 7      8    Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0   1   0     4
# 8      9     Merc 230  22.8    4  140.8   95  3.92  3.15  22.9   1   0     4
# 9     10     Merc 280  19.2    6  167.6  123  3.92  3.44  18.3   1   0     4
# 10    11    Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9   1   0     4
# 11    12   Merc 450SE  16.4    8  275.8  180  3.07  4.07  17.4   1   0     3
# 12    13   Merc 450SL  17.3    8  275.8  180  3.07  3.73  17.6   1   0     3
# 13    14  Merc 450SLC  15.2    8  275.8  180  3.07  3.78  18.0   1   0     3
#
#     carb   kmpl  kmpl2
# 7      2  31.72  58.56
# 8      2  29.64  54.72
# 9      4  24.96  46.08
# 10     4  23.14  42.72
# 11     3  21.32  39.36
# 12     3  22.49  41.52
# 13     3  19.76  36.48

# %%
df[(df["Unnamed: 1"].str.contains("Merc")) & (df["gear"] == 4 )]
# Out:
#     S.No Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  \
# 7      8  Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0   1   0     4
# 8      9   Merc 230  22.8    4  140.8   95  3.92  3.15  22.9   1   0     4
# 9     10   Merc 280  19.2    6  167.6  123  3.92  3.44  18.3   1   0     4
# 10    11  Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9   1   0     4
#
#     carb   kmpl  kmpl2
# 7      2  31.72  58.56
# 8      2  29.64  54.72
# 9      4  24.96  46.08
# 10     4  23.14  42.72

# %%
df[df['Unnamed: 1'].str.contains('Merc') | df['Unnamed: 1'].str.contains('Ford')]
# Out:
#     S.No      Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  \
# 7      8       Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0   1   0
# 8      9        Merc 230  22.8    4  140.8   95  3.92  3.15  22.9   1   0
# 9     10        Merc 280  19.2    6  167.6  123  3.92  3.44  18.3   1   0
# 10    11       Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9   1   0
# 11    12      Merc 450SE  16.4    8  275.8  180  3.07  4.07  17.4   1   0
# 12    13      Merc 450SL  17.3    8  275.8  180  3.07  3.73  17.6   1   0
# 13    14     Merc 450SLC  15.2    8  275.8  180  3.07  3.78  18.0   1   0
# 28    29  Ford Pantera L  15.8    8  351.0  264  4.22  3.17  14.5   1   1
#
#     gear  carb   kmpl  kmpl2
# 7      4     2  31.72  58.56
# 8      4     2  29.64  54.72
# 9      4     4  24.96  46.08
# 10     4     4  23.14  42.72
# 11     3     3  21.32  39.36
# 12     3     3  22.49  41.52
# 13     3     3  19.76  36.48
# 28     5     4  20.54  37.92

# %%
df[(df['Unnamed: 1']=='Merc') | (df['Unnamed: 1']=='Ford')]
# Out:
# Empty DataFrame
# Columns: [S.No, Unnamed: 1, mpg, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb, kmpl, kmpl2]
# Index: []
